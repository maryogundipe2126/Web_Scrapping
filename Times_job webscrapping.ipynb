# %%
import requests
import pandas as pd
import time
from bs4 import BeautifulSoup

# %%
url = 'https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=machine+learning&txtLocation='

# %%
page = requests.get(url).text

# %%
soup = BeautifulSoup(page, 'lxml')

# %%
company_name = []
result = soup.select('li h3')
for r in range(len(result)):
    company_name.append(result[r].text.rstrip().strip('(More Jobs)').strip('\r\n'))
company_name
# Out:
# ['    APPLYCUP HIRING SOLUTIONS LLP',
#  '    corner stone solution',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    serendipity',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Maxgen Technologies',
#  '    Priyanka Vinayak',
#  '    Priyanka Vinayak',
#  '    Priyanka Vinayak',
#  '    Priyanka Vinayak',
#  '    TECHNOPARK TRIVANDRU',
#  '    Cybage Software Pvt Ltd',
#  '    pattern effects labs private limited',
#  '    Vitrana',
#  '    Cybage Software Pvt Ltd',
#  '    e-con systems india pvt.ltd.',
#  '    Cotocu',
#  '    Cotocu',
#  '    Nse IT Ltd']

# %%
result = soup.select('li span[class="srp-skills"]')
skills = [r.text.replace('\r\n', '').strip() for r in result]
skills
# Out:
# ['image processing  ,  algorithms  ,  python  ,  c    ,  c  ,  natural language processing  ,  machine learning  ,  opencv',
#  'algorithms  ,  bi  ,  image processing  ,  python  ,  natural language processing  ,  machine learning  ,  opencv',
#  'freshers  ,  machine learning  ,  jobs',
#  'machine learning  ,  panda',
#  'internship  ,  machine learning  ,  ai',
#  'hiring  ,  programming  ,  machine learning',
#  'machine learning  ,  deep learning  ,  python',
#  'machine learning  ,  Artificial Intelligence  ,  mca',
#  'gujarat  ,  html  ,  machine learning  ,  ai',
#  'internship  ,  python',
#  'web  ,  programming  ,  machien learning  ,  internship',
#  'developer  ,  machine leraning  ,  internship',
#  'Finance  ,  Tally  ,  Tds  ,  Accounting  ,  Accountant  ,  assistant accountant',
#  'Finance  ,  Tally  ,  Tds  ,  Accounting  ,  Accountant  ,  assistant accountant',
#  'Finance  ,  Tally  ,  Tds  ,  Accounting  ,  Accountant  ,  assistant accountant',
#  'Finance  ,  Tally  ,  Tds  ,  Accounting  ,  Accountant',
#  'python  ,  machine learning  ,  opencv',
#  'python  ,  java  ,  machine learning',
#  'algorithms  ,  machine learning  ,   Boosting',
#  'algorithms  ,  python  ,  machine learning',
#  'algorithms  ,  python  ,  java  ,  machine learning',
#  'algorithms  ,  c    ,  oops  ,  machine learning  ,  machine vision',
#  'machine learning  ,  artificial intelligence  ,  docker',
#  'machine learning  ,  docker  ,   data science',
#  'algorithms  ,  python  ,  machine learning  ,  java  ,  data structures']

# %%
result = soup.select('ul[class="list-job-dtl clearfix"]')
job_descrip = [r.text.split('\n\n')[1].strip().replace('\r\n', '' ).replace('Job Description:', '') for r in result]
job_descrip[:5]
# Out:
# ['Qualification : B.E. / M.E. / M.C.A. / B.Tech / M.Tech ( Any IT Background )  Experience : 1 - 2 YearsSkills : Tensor Flow ,  Keras ,  AWS ,  Lambda ,  MongolDB ,  Image Proce... More Details',
#  'Machine Learning ,  Deep Learning ,  Python / R ,  Keras ,  Tensorflow ,  OpenCV ,  Regression ,  Clustering ,  AWS.Statistics  /  Mathematics: Data Quality Analysis ,  Data i... More Details',
#  'Maxgen technologies pvt ltd offering internship in Ahmedabad. candidate will get live project internship in python , machine learning  , data science. What you achieve in inte... More Details',
#  'Maxgen technologies pvt ltd offering internship in Ahmedabad. Candidates will get live project internship python  ,  machine learning  , ai. what we serve in an internship mul... More Details',
#  'Maxgen technologies pvt ltd offering live project internship in Ahmedabad. we are offering an internship in Machine Leraning and Ai.why us?We offer live project. We provide lo... More Details']

# %%
result = soup.select('ul[class="top-jd-dtl clearfix"]')
result[:5]
# Out:
# [<ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>1 - 2 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad">Ahmedabad</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>3 - 6 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Indore,  Bengaluru / Bangalore">Indore,  Bengaluru / Bangalore</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
#  </li>
#  </ul>]

# %%
location = [r.text.split()[-1] for r in result]
location
# Out:
# ['Ahmedabad',
#  'Bangalore',
#  'Surendranagar',
#  'Surendranagar',
#  'Mehsana',
#  'Mehsana',
#  'Bangalore',
#  'Thane',
#  'Surendranagar',
#  'Surendranagar',
#  'Solapur',
#  'Solapur',
#  'Jorhat',
#  'Jorhat',
#  'Dhubri',
#  'Silchar',
#  'Thiruvananthapuram',
#  'Pune',
#  'Bangalore',
#  'Bangalore',
#  'Pune',
#  'Chennai',
#  'Bangalore',
#  'Bangalore',
#  'Mumbai']

# %%
experience = soup.select('ul[class="top-jd-dtl clearfix"]')
experience[:5]
# Out:
# [<ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>1 - 2 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad">Ahmedabad</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>3 - 6 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Indore,  Bengaluru / Bangalore">Indore,  Bengaluru / Bangalore</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar">Ahmedabad,  Mehsana,  Rajkot,  Surat,  Surendranagar</span>
#  </li>
#  </ul>,
#  <ul class="top-jd-dtl clearfix">
#  <li><i class="material-icons">card_travel</i>0 - 1 yrs</li>
#  <li>
#  <i class="material-icons">location_on</i>
#  <span title="Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana">Ahmedabad,  Bhavnagar,  Gandhinagar,  Jamnagar,  Mehsana</span>
#  </li>
#  </ul>]

# %%
year_exp = [r.text.split('\n')[1].replace('card_travel', '') for r in experience]
year_exp
# Out:
# ['1 - 2 yrs',
#  '3 - 6 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '4 - 9 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 1 yrs',
#  '0 - 2 yrs',
#  '0 - 2 yrs',
#  '0 - 2 yrs',
#  '0 - 1 yrs',
#  '3 - 4 yrs',
#  '6 - 9 yrs',
#  '2 - 5 yrs',
#  '2 - 4 yrs',
#  '6 - 9 yrs',
#  '0 - 4 yrs',
#  '8 - 11 yrs',
#  '0 - 3 yrs',
#  '2 - 3 yrs']

# %%
page_info = list(zip(company_name,skills,job_descrip,location,year_exp))
page_info[:5]
# Out:
# [('    APPLYCUP HIRING SOLUTIONS LLP',
#   'image processing  ,  algorithms  ,  python  ,  c    ,  c  ,  natural language processing  ,  machine learning  ,  opencv',
#   'Qualification : B.E. / M.E. / M.C.A. / B.Tech / M.Tech ( Any IT Background )  Experience : 1 - 2 YearsSkills : Tensor Flow ,  Keras ,  AWS ,  Lambda ,  MongolDB ,  Image Proce... More Details',
#   'Ahmedabad',
#   '1 - 2 yrs'),
#  ('    corner stone solution',
#   'algorithms  ,  bi  ,  image processing  ,  python  ,  natural language processing  ,  machine learning  ,  opencv',
#   'Machine Learning ,  Deep Learning ,  Python / R ,  Keras ,  Tensorflow ,  OpenCV ,  Regression ,  Clustering ,  AWS.Statistics  /  Mathematics: Data Quality Analysis ,  Data i... More Details',
#   'Bangalore',
#   '3 - 6 yrs'),
#  ('    Maxgen Technologies',
#   'freshers  ,  machine learning  ,  jobs',
#   'Maxgen technologies pvt ltd offering internship in Ahmedabad. candidate will get live project internship in python , machine learning  , data science. What you achieve in inte... More Details',
#   'Surendranagar',
#   '0 - 1 yrs'),
#  ('    Maxgen Technologies',
#   'machine learning  ,  panda',
#   'Maxgen technologies pvt ltd offering internship in Ahmedabad. Candidates will get live project internship python  ,  machine learning  , ai. what we serve in an internship mul... More Details',
#   'Surendranagar',
#   '0 - 1 yrs'),
#  ('    Maxgen Technologies',
#   'internship  ,  machine learning  ,  ai',
#   'Maxgen technologies pvt ltd offering live project internship in Ahmedabad. we are offering an internship in Machine Leraning and Ai.why us?We offer live project. We provide lo... More Details',
#   'Mehsana',
#   '0 - 1 yrs')]

# %%
page_df = pd.DataFrame(page_info,  columns=['comp_name','key_skills', 'job_description', 'location', 'years of exp'])
page_df
# Out:
#                                    comp_name  \
# 0              APPLYCUP HIRING SOLUTIONS LLP
# 1                      corner stone solution
# 2                        Maxgen Technologies
# 3                        Maxgen Technologies
# 4                        Maxgen Technologies
# 5                        Maxgen Technologies
# 6                                serendipity
# 7                        Maxgen Technologies
# 8                        Maxgen Technologies
# 9                        Maxgen Technologies
# 10                       Maxgen Technologies
# 11                       Maxgen Technologies
# 12                          Priyanka Vinayak
# 13                          Priyanka Vinayak
# 14                          Priyanka Vinayak
# 15                          Priyanka Vinayak
# 16                      TECHNOPARK TRIVANDRU
# 17                   Cybage Software Pvt Ltd
# 18      pattern effects labs private limited
# 19                                   Vitrana
# 20                   Cybage Software Pvt Ltd
# 21              e-con systems india pvt.ltd.
# 22                                    Cotocu
# 23                                    Cotocu
# 24                                Nse IT Ltd
#
#                                            key_skills  \
# 0   image processing  ,  algorithms  ,  python  , ...
# 1   algorithms  ,  bi  ,  image processing  ,  pyt...
# 2              freshers  ,  machine learning  ,  jobs
# 3                          machine learning  ,  panda
# 4              internship  ,  machine learning  ,  ai
# 5         hiring  ,  programming  ,  machine learning
# 6       machine learning  ,  deep learning  ,  python
# 7   machine learning  ,  Artificial Intelligence  ...
# 8        gujarat  ,  html  ,  machine learning  ,  ai
# 9                               internship  ,  python
# 10  web  ,  programming  ,  machien learning  ,  i...
# 11      developer  ,  machine leraning  ,  internship
# 12  Finance  ,  Tally  ,  Tds  ,  Accounting  ,  A...
# 13  Finance  ,  Tally  ,  Tds  ,  Accounting  ,  A...
# 14  Finance  ,  Tally  ,  Tds  ,  Accounting  ,  A...
# 15  Finance  ,  Tally  ,  Tds  ,  Accounting  ,  A...
# 16             python  ,  machine learning  ,  opencv
# 17               python  ,  java  ,  machine learning
# 18      algorithms  ,  machine learning  ,   Boosting
# 19         algorithms  ,  python  ,  machine learning
# 20  algorithms  ,  python  ,  java  ,  machine lea...
# 21  algorithms  ,  c    ,  oops  ,  machine learni...
# 22  machine learning  ,  artificial intelligence  ...
# 23      machine learning  ,  docker  ,   data science
# 24  algorithms  ,  python  ,  machine learning  , ...
#
#                                       job_description            location  \
# 0   Qualification : B.E. / M.E. / M.C.A. / B.Tech ...           Ahmedabad
# 1   Machine Learning ,  Deep Learning ,  Python / ...           Bangalore
# 2   Maxgen technologies pvt ltd offering internshi...       Surendranagar
# 3   Maxgen technologies pvt ltd offering internshi...       Surendranagar
# 4   Maxgen technologies pvt ltd offering live proj...             Mehsana
# 5   Maxgen technologies pvt ltd offering live proj...             Mehsana
# 6    Hands on experience in Python programming ,  ...           Bangalore
# 7   Maxgen technologies Pvt ltd offers live projec...               Thane
# 8   Maxgen Technologies Pvt Ltd offering LiveProje...       Surendranagar
# 9   Maxgen technologies pvt ltd offering internshi...       Surendranagar
# 10  Maxgen Technologies Pvt Ltd offering College P...             Solapur
# 11  Maxgen Technologies Pvt Ltd offering College P...             Solapur
# 12  Remote Recruiter: As a remote Recruiter ,  you...              Jorhat
# 13  Remote Recruiter: As a remote Recruiter ,  you...              Jorhat
# 14  Protecting what matters most to our associates...              Dhubri
# 15  Digital Marketer: As a Digital Marketer ,  you...             Silchar
# 16  Brief description :Machine learning Engineers ...  Thiruvananthapuram
# 17  Experience: 6-9 YearsTo be the right fit ,  yo...                Pune
# 18  Machine Learning AnalystLooking for machine le...           Bangalore
# 19  Responsibilities:Study and transform data scie...           Bangalore
# 20  Experience: 6  yearsThe key aspects of this ro...                Pune
# 21  Skillsets:Programming knowledge - Must be good...             Chennai
# 22  Job Description General RequirementPreferably ...           Bangalore
# 23  Job Description Autodesk is seeking a Machine ...           Bangalore
# 24  Desired Skills  &  ExperienceOutcomesIndepende...              Mumbai
#
#    years of exp
# 0     1 - 2 yrs
# 1     3 - 6 yrs
# 2     0 - 1 yrs
# 3     0 - 1 yrs
# 4     0 - 1 yrs
# 5     0 - 1 yrs
# 6     4 - 9 yrs
# 7     0 - 1 yrs
# 8     0 - 1 yrs
# 9     0 - 1 yrs
# 10    0 - 1 yrs
# 11    0 - 1 yrs
# 12    0 - 2 yrs
# 13    0 - 2 yrs
# 14    0 - 2 yrs
# 15    0 - 1 yrs
# 16    3 - 4 yrs
# 17    6 - 9 yrs
# 18    2 - 5 yrs
# 19    2 - 4 yrs
# 20    6 - 9 yrs
# 21    0 - 4 yrs
# 22   8 - 11 yrs
# 23    0 - 3 yrs
# 24    2 - 3 yrs
